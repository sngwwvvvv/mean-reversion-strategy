# %% [markdown]
# <a href="https://colab.research.google.com/github/sngwwvvvv/mean-reversion-strategy/blob/main/mean_reversion_strategy_with_fees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating a Mean Reversion strategy

# %% [markdown]
# In this video, we are going to create a professional mean reversion strategy
#
# Want to show how mean reversion is traded professionally as what you see on the internet is not 100% accurate.
#
# This is a strategy that you can trade manually or automatically.
#
# I'm a strong advocate of simplicity and this strategy is not going to use any machine-learning nor advanced mathematics.
#
# It's just going to be using basic econometrics.
#
# Financial data is extremely noisy yet there are statistical patterns that exhibit inside that are not visible to the naked eye.
# There's a misconception that you cannot make money with basic strategies because the markets are complex - this is futher from the truth.

# %% [markdown]
# ## Goal = Find a statistical pattern

# %% [markdown]
# ![Alt text](https://i.postimg.cc/023pdYK0/BCH.png)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We have Bitcoin Cash data. I know nothing about this project or coin or the history. All that I am interested in is its price movements.

# %%
url = "https://drive.google.com/uc?export=download&id=1eQN7nCrv1byqqX8oIt1Ks6SlDFb_ySlc"
df = pd.read_csv(url)
del df['Unnamed: 0']
df
# Out:
#                t                        T    s   i       o       c       h  \
# 0     2022-04-13  2022-04-13 23:59:59.999  BCH  1d  304.73  340.90  349.63
# 1     2022-04-14  2022-04-14 23:59:59.999  BCH  1d  340.90  337.42  353.00
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 0     301.03     0.000     0               NaN                     NaN
# 1     332.34     0.000     0         -0.010261                     NaN
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir
# 0                       -1                          -1
# 1                       -1                          -1
# 2                        1                          -1
# 3                        1                           1
# 4                       -1                           1
# ...                    ...                         ...
# 1456                    -1                           1
# 1457                     1                          -1
# 1458                     1                           1
# 1459                    -1                           1
# 1460                    -1                          -1
#
# [1461 rows x 14 columns]

# %% [markdown]
# ## Create Log Returns

# %%
df['close_log_return'] = np.log(df['c']/df['c'].shift(1))
df
# Out:
#                t                        T    s   i       o       c       h  \
# 0     2022-04-13  2022-04-13 23:59:59.999  BCH  1d  304.73  340.90  349.63
# 1     2022-04-14  2022-04-14 23:59:59.999  BCH  1d  340.90  337.42  353.00
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 0     301.03     0.000     0               NaN                     NaN
# 1     332.34     0.000     0         -0.010261                     NaN
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir
# 0                       -1                          -1
# 1                       -1                          -1
# 2                        1                          -1
# 3                        1                           1
# 4                       -1                           1
# ...                    ...                         ...
# 1456                    -1                           1
# 1457                     1                          -1
# 1458                     1                           1
# 1459                    -1                           1
# 1460                    -1                          -1
#
# [1461 rows x 14 columns]

# %% [markdown]
# ## Create Auto-Regressive Log Returns

# %%
df['close_log_return_lag_1'] = df['close_log_return'].shift(1)
df = df.dropna()
df
# Out:
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir
# 2                        1                          -1
# 3                        1                           1
# 4                       -1                           1
# 5                        1                          -1
# 6                        1                           1
# ...                    ...                         ...
# 1456                    -1                           1
# 1457                     1                          -1
# 1458                     1                           1
# 1459                    -1                           1
# 1460                    -1                          -1
#
# [1459 rows x 14 columns]

# %% [markdown]
# ## Encode Direction
#
# * 1 => Long => Bet up
# * -1 => Short => Bet down

# %%
for col in ['close_log_return','close_log_return_lag_1']:
    df[f'{col}_dir'] = df[col].map(lambda x: 1 if x > 0 else -1)
df
# Out:
# /tmp/ipykernel_5418/37754665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_dir'] = df[col].map(lambda x: 1 if x > 0 else -1)
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir
# 2                        1                          -1
# 3                        1                           1
# 4                       -1                           1
# 5                        1                          -1
# 6                        1                           1
# ...                    ...                         ...
# 1456                    -1                           1
# 1457                     1                          -1
# 1458                     1                           1
# 1459                    -1                           1
# 1460                    -1                          -1
#
# [1459 rows x 14 columns]

# %% [markdown]
# ## Study Auto-Regressive Price Movements

# %%
df.groupby('close_log_return_lag_1_dir').aggregate({'close_log_return':['mean','count', 'sum']})
# Out:
#                            close_log_return
#                                        mean count       sum
# close_log_return_lag_1_dir
# -1                                 0.002281   734  1.674421
#  1                                -0.001990   725 -1.442438

# %% [markdown]
# ## How to interpret this?
#
# Well it exhibits strong mean reversion behaviour
#
# 1. If the previous price movement went down, it has a strong price movement that it will go up in the next day.
# 2. If the previous price movement went up, it has a strong price movement that it will go down in the next day.

# %% [markdown]
# ## Out-of-Sample Validation
#
# To determine whether the observed pattern persists over time rather than being a temporary effect, the statistic is evaluated on a holdout dataset consisting of the most recent observations.
#
# This ensures that the results generalize beyond the in-sample period.

# %%
i = int(len(df) * 0.75)

in_sample, out_sample = df.iloc[:i], df.iloc[i:]

in_sample.groupby('close_log_return_lag_1_dir').aggregate({'close_log_return':['mean','count', 'sum']})
# Out:
#                            close_log_return
#                                        mean count       sum
# close_log_return_lag_1_dir
# -1                                 0.002007   553  1.109951
#  1                                -0.002014   541 -1.089592

# %%
out_sample.groupby('close_log_return_lag_1_dir').aggregate({'close_log_return':['mean','count', 'sum']})
# Out:
#                            close_log_return
#                                        mean count       sum
# close_log_return_lag_1_dir
# -1                                 0.003119   181  0.564470
#  1                                -0.001918   184 -0.352846

# %% [markdown]
# We can see the pattern persists in the out-of-sample so this means that the mean reversion behaviour persists with the most recent data.

# %% [markdown]
# ## Display Equity Curve

# %% [markdown]
# We are interested to know what the equity curve looks like if we traded this mean reversion strategy.

# %%
df['signal'] = -1 * df['close_log_return_lag_1_dir']
df
# Out:
# /tmp/ipykernel_5418/2769368292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['signal'] = -1 * df['close_log_return_lag_1_dir']
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir  signal
# 2                        1                          -1       1
# 3                        1                           1      -1
# 4                       -1                           1      -1
# 5                        1                          -1       1
# 6                        1                           1      -1
# ...                    ...                         ...     ...
# 1456                    -1                           1      -1
# 1457                     1                          -1       1
# 1458                     1                           1      -1
# 1459                    -1                           1      -1
# 1460                    -1                          -1       1
#
# [1459 rows x 15 columns]

# %%
df['trade_log_return'] = df['signal'] * df['close_log_return']
df
# Out:
# /tmp/ipykernel_5418/2468843582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['trade_log_return'] = df['signal'] * df['close_log_return']
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir  signal  \
# 2                        1                          -1       1
# 3                        1                           1      -1
# 4                       -1                           1      -1
# 5                        1                          -1       1
# 6                        1                           1      -1
# ...                    ...                         ...     ...
# 1456                    -1                           1      -1
# 1457                     1                          -1       1
# 1458                     1                           1      -1
# 1459                    -1                           1      -1
# 1460                    -1                          -1       1
#
#       trade_log_return
# 2             0.009439
# 3            -0.005738
# 4             0.043949
# 5             0.037095
# 6            -0.000118
# ...                ...
# 1456          0.010372
# 1457          0.003416
# 1458         -0.001986
# 1459          0.014281
# 1460         -0.027353
#
# [1459 rows x 16 columns]

# %%
df['trade_log_return'].cumsum().plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Strategy Statistics

# %% [markdown]
# Win Rate

# %%
df['is_won'] = df['trade_log_return'] > 0
df['is_won'].mean()
# Out:
# /tmp/ipykernel_5418/3864770056.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_won'] = df['trade_log_return'] > 0
# np.float64(0.5291295407813571)

# %% [markdown]
# Total Gross Compound Return

# %%
r = np.exp(df['trade_log_return'].sum()) - 1
r
# Out:
# np.float64(21.575359341230723)

# %%
12 * r
# Out:
# np.float64(258.90431209476867)

# %% [markdown]
# Annualized Sharpe

# %%
df['trade_log_return'].mean() / df['trade_log_return'].std() * np.sqrt(365)
# Out:
# np.float64(0.9449165289438253)

# %% [markdown]
# ## Add Round-Trip Fees

# %%
df['cum_trade_log_return'] = df['trade_log_return'].cumsum()
df
# Out:
# /tmp/ipykernel_5418/3441787508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cum_trade_log_return'] = df['trade_log_return'].cumsum()
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir  signal  \
# 2                        1                          -1       1
# 3                        1                           1      -1
# 4                       -1                           1      -1
# 5                        1                          -1       1
# 6                        1                           1      -1
# ...                    ...                         ...     ...
# 1456                    -1                           1      -1
# 1457                     1                          -1       1
# 1458                     1                           1      -1
# 1459                    -1                           1      -1
# 1460                    -1                          -1       1
#
#       trade_log_return  is_won  cum_trade_log_return
# 2             0.009439    True              0.009439
# 3            -0.005738   False              0.003701
# 4             0.043949    True              0.047650
# 5             0.037095    True              0.084745
# 6            -0.000118   False              0.084628
# ...                ...     ...                   ...
# 1456          0.010372    True              3.128501
# 1457          0.003416    True              3.131917
# 1458         -0.001986   False              3.129932
# 1459          0.014281    True              3.144212
# 1460         -0.027353   False              3.116859
#
# [1459 rows x 18 columns]

# %%
capital = 1000
df['post_trade_notional_value'] = capital + df['cum_trade_log_return'] * capital
df
# Out:
# /tmp/ipykernel_5418/532556028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['post_trade_notional_value'] = capital + df['cum_trade_log_return'] * capital
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir  signal  \
# 2                        1                          -1       1
# 3                        1                           1      -1
# 4                       -1                           1      -1
# 5                        1                          -1       1
# 6                        1                           1      -1
# ...                    ...                         ...     ...
# 1456                    -1                           1      -1
# 1457                     1                          -1       1
# 1458                     1                           1      -1
# 1459                    -1                           1      -1
# 1460                    -1                          -1       1
#
#       trade_log_return  is_won  cum_trade_log_return  \
# 2             0.009439    True              0.009439
# 3            -0.005738   False              0.003701
# 4             0.043949    True              0.047650
# 5             0.037095    True              0.084745
# 6            -0.000118   False              0.084628
# ...                ...     ...                   ...
# 1456          0.010372    True              3.128501
# 1457          0.003416    True              3.131917
# 1458         -0.001986   False              3.129932
# 1459          0.014281    True              3.144212
# 1460         -0.027353   False              3.116859
#
#       post_trade_notional_value
# 2                   1009.439041
# 3                   1003.701321
# 4                   1047.650341
# 5                   1084.745405
# 6                   1084.627848
# ...                         ...
# 1456                4128.500862
# 1457                4131.917348
# 1458                4129.931653
# 1459                4144.212259
# 1460                4116.859017
#
# [1459 rows x 19 columns]

# %%
df['pre_trade_notional_value'] = df['post_trade_notional_value'].shift()
df
# Out:
# /tmp/ipykernel_5418/3368718721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pre_trade_notional_value'] = df['post_trade_notional_value'].shift()
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir  signal  \
# 2                        1                          -1       1
# 3                        1                           1      -1
# 4                       -1                           1      -1
# 5                        1                          -1       1
# 6                        1                           1      -1
# ...                    ...                         ...     ...
# 1456                    -1                           1      -1
# 1457                     1                          -1       1
# 1458                     1                           1      -1
# 1459                    -1                           1      -1
# 1460                    -1                          -1       1
#
#       trade_log_return  is_won  cum_trade_log_return  \
# 2             0.009439    True              0.009439
# 3            -0.005738   False              0.003701
# 4             0.043949    True              0.047650
# 5             0.037095    True              0.084745
# 6            -0.000118   False              0.084628
# ...                ...     ...                   ...
# 1456          0.010372    True              3.128501
# 1457          0.003416    True              3.131917
# 1458         -0.001986   False              3.129932
# 1459          0.014281    True              3.144212
# 1460         -0.027353   False              3.116859
#
#       post_trade_notional_value  pre_trade_notional_value
# 2                   1009.439041                       NaN
# 3                   1003.701321               1009.439041
# 4                   1047.650341               1003.701321
# 5                   1084.745405               1047.650341
# 6                   1084.627848               1084.745405
# ...                         ...                       ...
# 1456                4128.500862               4118.129196
# 1457                4131.917348               4128.500862
# 1458                4129.931653               4131.917348
# 1459                4144.212259               4129.931653
# 1460                4116.859017               4144.212259
#
# [1459 rows x 20 columns]

# %%
df['pre_trade_notional_value'] = df['pre_trade_notional_value'].fillna(capital)
df
# Out:
# /tmp/ipykernel_5418/3998963307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pre_trade_notional_value'] = df['pre_trade_notional_value'].fillna(capital)
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  close_log_return  close_log_return_lag_1  \
# 2     333.08     0.000     0          0.009439               -0.010261
# 3     338.43     0.000     0          0.005738                0.009439
# 4     327.12     0.000     0         -0.043949                0.005738
# 5     312.59     0.000     0          0.037095               -0.043949
# 6     332.23     0.000     0          0.000118                0.037095
# ...      ...       ...   ...               ...                     ...
# 1456  439.88  3051.575  4525         -0.010372                0.025075
# 1457  433.03  4415.805  5588          0.003416               -0.010372
# 1458  434.19  4414.799  5688          0.001986                0.003416
# 1459  436.27  1886.537  3916         -0.014281                0.001986
# 1460  422.83  3278.733  2960         -0.027353               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir  signal  \
# 2                        1                          -1       1
# 3                        1                           1      -1
# 4                       -1                           1      -1
# 5                        1                          -1       1
# 6                        1                           1      -1
# ...                    ...                         ...     ...
# 1456                    -1                           1      -1
# 1457                     1                          -1       1
# 1458                     1                           1      -1
# 1459                    -1                           1      -1
# 1460                    -1                          -1       1
#
#       trade_log_return  is_won  cum_trade_log_return  \
# 2             0.009439    True              0.009439
# 3            -0.005738   False              0.003701
# 4             0.043949    True              0.047650
# 5             0.037095    True              0.084745
# 6            -0.000118   False              0.084628
# ...                ...     ...                   ...
# 1456          0.010372    True              3.128501
# 1457          0.003416    True              3.131917
# 1458         -0.001986   False              3.129932
# 1459          0.014281    True              3.144212
# 1460         -0.027353   False              3.116859
#
#       post_trade_notional_value  pre_trade_notional_value
# 2                   1009.439041               1000.000000
# 3                   1003.701321               1009.439041
# 4                   1047.650341               1003.701321
# 5                   1084.745405               1047.650341
# 6                   1084.627848               1084.745405
# ...                         ...                       ...
# 1456                4128.500862               4118.129196
# 1457                4131.917348               4128.500862
# 1458                4129.931653               4131.917348
# 1459                4144.212259               4129.931653
# 1460                4116.859017               4144.212259
#
# [1459 rows x 20 columns]

# %%
TAKER_FEE_BPS = 2.0
MAKER_FEE_BPS = 1.5

def fee_bps(bp):
  return bp / 10000

TAKER_FEE = fee_bps(TAKER_FEE_BPS)
MAKER_FEE = fee_bps(MAKER_FEE_BPS)
df['entry_fee'] = df['pre_trade_notional_value'] * MAKER_FEE
df
# Out:
# /tmp/ipykernel_5418/1467138052.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['entry_fee'] = df['pre_trade_notional_value'] * MAKER_FEE
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  ...  close_log_return_lag_1  \
# 2     333.08     0.000     0  ...               -0.010261
# 3     338.43     0.000     0  ...                0.009439
# 4     327.12     0.000     0  ...                0.005738
# 5     312.59     0.000     0  ...               -0.043949
# 6     332.23     0.000     0  ...                0.037095
# ...      ...       ...   ...  ...                     ...
# 1456  439.88  3051.575  4525  ...                0.025075
# 1457  433.03  4415.805  5588  ...               -0.010372
# 1458  434.19  4414.799  5688  ...                0.003416
# 1459  436.27  1886.537  3916  ...                0.001986
# 1460  422.83  3278.733  2960  ...               -0.014281
#
#       close_log_return_dir  close_log_return_lag_1_dir  signal  \
# 2                        1                          -1       1
# 3                        1                           1      -1
# 4                       -1                           1      -1
# 5                        1                          -1       1
# 6                        1                           1      -1
# ...                    ...                         ...     ...
# 1456                    -1                           1      -1
# 1457                     1                          -1       1
# 1458                     1                           1      -1
# 1459                    -1                           1      -1
# 1460                    -1                          -1       1
#
#       trade_log_return  is_won  cum_trade_log_return  \
# 2             0.009439    True              0.009439
# 3            -0.005738   False              0.003701
# 4             0.043949    True              0.047650
# 5             0.037095    True              0.084745
# 6            -0.000118   False              0.084628
# ...                ...     ...                   ...
# 1456          0.010372    True              3.128501
# 1457          0.003416    True              3.131917
# 1458         -0.001986   False              3.129932
# 1459          0.014281    True              3.144212
# 1460         -0.027353   False              3.116859
#
#       post_trade_notional_value  pre_trade_notional_value  entry_fee
# 2                   1009.439041               1000.000000   0.150000
# 3                   1003.701321               1009.439041   0.151416
# 4                   1047.650341               1003.701321   0.150555
# 5                   1084.745405               1047.650341   0.157148
# 6                   1084.627848               1084.745405   0.162712
# ...                         ...                       ...        ...
# 1456                4128.500862               4118.129196   0.617719
# 1457                4131.917348               4128.500862   0.619275
# 1458                4129.931653               4131.917348   0.619788
# 1459                4144.212259               4129.931653   0.619490
# 1460                4116.859017               4144.212259   0.621632
#
# [1459 rows x 21 columns]

# %%
df['exit_fee'] = df['post_trade_notional_value'] * MAKER_FEE
df
# Out:
# /tmp/ipykernel_5418/1553471733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['exit_fee'] = df['post_trade_notional_value'] * MAKER_FEE
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  ...  close_log_return_dir  \
# 2     333.08     0.000     0  ...                     1
# 3     338.43     0.000     0  ...                     1
# 4     327.12     0.000     0  ...                    -1
# 5     312.59     0.000     0  ...                     1
# 6     332.23     0.000     0  ...                     1
# ...      ...       ...   ...  ...                   ...
# 1456  439.88  3051.575  4525  ...                    -1
# 1457  433.03  4415.805  5588  ...                     1
# 1458  434.19  4414.799  5688  ...                     1
# 1459  436.27  1886.537  3916  ...                    -1
# 1460  422.83  3278.733  2960  ...                    -1
#
#       close_log_return_lag_1_dir  signal  trade_log_return  is_won  \
# 2                             -1       1          0.009439    True
# 3                              1      -1         -0.005738   False
# 4                              1      -1          0.043949    True
# 5                             -1       1          0.037095    True
# 6                              1      -1         -0.000118   False
# ...                          ...     ...               ...     ...
# 1456                           1      -1          0.010372    True
# 1457                          -1       1          0.003416    True
# 1458                           1      -1         -0.001986   False
# 1459                           1      -1          0.014281    True
# 1460                          -1       1         -0.027353   False
#
#       cum_trade_log_return  post_trade_notional_value  \
# 2                 0.009439                1009.439041
# 3                 0.003701                1003.701321
# 4                 0.047650                1047.650341
# 5                 0.084745                1084.745405
# 6                 0.084628                1084.627848
# ...                    ...                        ...
# 1456              3.128501                4128.500862
# 1457              3.131917                4131.917348
# 1458              3.129932                4129.931653
# 1459              3.144212                4144.212259
# 1460              3.116859                4116.859017
#
#       pre_trade_notional_value  entry_fee  exit_fee
# 2                  1000.000000   0.150000  0.151416
# 3                  1009.439041   0.151416  0.150555
# 4                  1003.701321   0.150555  0.157148
# 5                  1047.650341   0.157148  0.162712
# 6                  1084.745405   0.162712  0.162694
# ...                        ...        ...       ...
# 1456               4118.129196   0.617719  0.619275
# 1457               4128.500862   0.619275  0.619788
# 1458               4131.917348   0.619788  0.619490
# 1459               4129.931653   0.619490  0.621632
# 1460               4144.212259   0.621632  0.617529
#
# [1459 rows x 22 columns]

# %%
df['roundtrip_fees'] = df['entry_fee'] + df['exit_fee']
df
# Out:
# /tmp/ipykernel_5418/3835782523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['roundtrip_fees'] = df['entry_fee'] + df['exit_fee']
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  ...  close_log_return_lag_1_dir  signal  \
# 2     333.08     0.000     0  ...                          -1       1
# 3     338.43     0.000     0  ...                           1      -1
# 4     327.12     0.000     0  ...                           1      -1
# 5     312.59     0.000     0  ...                          -1       1
# 6     332.23     0.000     0  ...                           1      -1
# ...      ...       ...   ...  ...                         ...     ...
# 1456  439.88  3051.575  4525  ...                           1      -1
# 1457  433.03  4415.805  5588  ...                          -1       1
# 1458  434.19  4414.799  5688  ...                           1      -1
# 1459  436.27  1886.537  3916  ...                           1      -1
# 1460  422.83  3278.733  2960  ...                          -1       1
#
#       trade_log_return  is_won  cum_trade_log_return  \
# 2             0.009439    True              0.009439
# 3            -0.005738   False              0.003701
# 4             0.043949    True              0.047650
# 5             0.037095    True              0.084745
# 6            -0.000118   False              0.084628
# ...                ...     ...                   ...
# 1456          0.010372    True              3.128501
# 1457          0.003416    True              3.131917
# 1458         -0.001986   False              3.129932
# 1459          0.014281    True              3.144212
# 1460         -0.027353   False              3.116859
#
#       post_trade_notional_value  pre_trade_notional_value  entry_fee  \
# 2                   1009.439041               1000.000000   0.150000
# 3                   1003.701321               1009.439041   0.151416
# 4                   1047.650341               1003.701321   0.150555
# 5                   1084.745405               1047.650341   0.157148
# 6                   1084.627848               1084.745405   0.162712
# ...                         ...                       ...        ...
# 1456                4128.500862               4118.129196   0.617719
# 1457                4131.917348               4128.500862   0.619275
# 1458                4129.931653               4131.917348   0.619788
# 1459                4144.212259               4129.931653   0.619490
# 1460                4116.859017               4144.212259   0.621632
#
#       exit_fee  roundtrip_fees
# 2     0.151416        0.301416
# 3     0.150555        0.301971
# 4     0.157148        0.307703
# 5     0.162712        0.319859
# 6     0.162694        0.325406
# ...        ...             ...
# 1456  0.619275        1.236995
# 1457  0.619788        1.239063
# 1458  0.619490        1.239277
# 1459  0.621632        1.241122
# 1460  0.617529        1.239161
#
# [1459 rows x 23 columns]

# %%
df['cum_roundtrip_fees'] = df['roundtrip_fees'].cumsum()
df
# Out:
# /tmp/ipykernel_5418/1918195950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cum_roundtrip_fees'] = df['roundtrip_fees'].cumsum()
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  ...  signal  trade_log_return  is_won  \
# 2     333.08     0.000     0  ...       1          0.009439    True
# 3     338.43     0.000     0  ...      -1         -0.005738   False
# 4     327.12     0.000     0  ...      -1          0.043949    True
# 5     312.59     0.000     0  ...       1          0.037095    True
# 6     332.23     0.000     0  ...      -1         -0.000118   False
# ...      ...       ...   ...  ...     ...               ...     ...
# 1456  439.88  3051.575  4525  ...      -1          0.010372    True
# 1457  433.03  4415.805  5588  ...       1          0.003416    True
# 1458  434.19  4414.799  5688  ...      -1         -0.001986   False
# 1459  436.27  1886.537  3916  ...      -1          0.014281    True
# 1460  422.83  3278.733  2960  ...       1         -0.027353   False
#
#       cum_trade_log_return  post_trade_notional_value  \
# 2                 0.009439                1009.439041
# 3                 0.003701                1003.701321
# 4                 0.047650                1047.650341
# 5                 0.084745                1084.745405
# 6                 0.084628                1084.627848
# ...                    ...                        ...
# 1456              3.128501                4128.500862
# 1457              3.131917                4131.917348
# 1458              3.129932                4129.931653
# 1459              3.144212                4144.212259
# 1460              3.116859                4116.859017
#
#       pre_trade_notional_value  entry_fee  exit_fee  roundtrip_fees  \
# 2                  1000.000000   0.150000  0.151416        0.301416
# 3                  1009.439041   0.151416  0.150555        0.301971
# 4                  1003.701321   0.150555  0.157148        0.307703
# 5                  1047.650341   0.157148  0.162712        0.319859
# 6                  1084.745405   0.162712  0.162694        0.325406
# ...                        ...        ...       ...             ...
# 1456               4118.129196   0.617719  0.619275        1.236995
# 1457               4128.500862   0.619275  0.619788        1.239063
# 1458               4131.917348   0.619788  0.619490        1.239277
# 1459               4129.931653   0.619490  0.621632        1.241122
# 1460               4144.212259   0.621632  0.617529        1.239161
#
#       cum_roundtrip_fees
# 2               0.301416
# 3               0.603387
# 4               0.911090
# 5               1.230949
# 6               1.556355
# ...                  ...
# 1456         1142.772120
# 1457         1144.011183
# 1458         1145.250460
# 1459         1146.491582
# 1460         1147.730742
#
# [1459 rows x 24 columns]

# %%
df['net_equity'] = df['post_trade_notional_value'] - df['cum_roundtrip_fees']
df
# Out:
# /tmp/ipykernel_5418/1974530036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['net_equity'] = df['post_trade_notional_value'] - df['cum_roundtrip_fees']
#                t                        T    s   i       o       c       h  \
# 2     2022-04-15  2022-04-15 23:59:59.999  BCH  1d  337.41  340.62  345.29
# 3     2022-04-16  2022-04-16 23:59:59.999  BCH  1d  340.63  342.58  347.61
# 4     2022-04-17  2022-04-17 23:59:59.999  BCH  1d  342.58  327.85  348.81
# 5     2022-04-18  2022-04-18 23:59:59.999  BCH  1d  327.80  340.24  340.95
# 6     2022-04-19  2022-04-19 23:59:59.999  BCH  1d  340.26  340.28  343.00
# ...          ...                      ...  ...  ..     ...     ...     ...
# 1456  2026-04-08  2026-04-08 23:59:59.999  BCH  1d  445.80  441.22  449.44
# 1457  2026-04-09  2026-04-09 23:59:59.999  BCH  1d  441.11  442.73  446.27
# 1458  2026-04-10  2026-04-10 23:59:59.999  BCH  1d  442.82  443.61  446.66
# 1459  2026-04-11  2026-04-11 23:59:59.999  BCH  1d  443.56  437.32  445.06
# 1460  2026-04-12  2026-04-12 23:59:59.999  BCH  1d  437.32  425.52  437.76
#
#            l         v     n  ...  trade_log_return  is_won  \
# 2     333.08     0.000     0  ...          0.009439    True
# 3     338.43     0.000     0  ...         -0.005738   False
# 4     327.12     0.000     0  ...          0.043949    True
# 5     312.59     0.000     0  ...          0.037095    True
# 6     332.23     0.000     0  ...         -0.000118   False
# ...      ...       ...   ...  ...               ...     ...
# 1456  439.88  3051.575  4525  ...          0.010372    True
# 1457  433.03  4415.805  5588  ...          0.003416    True
# 1458  434.19  4414.799  5688  ...         -0.001986   False
# 1459  436.27  1886.537  3916  ...          0.014281    True
# 1460  422.83  3278.733  2960  ...         -0.027353   False
#
#       cum_trade_log_return  post_trade_notional_value  \
# 2                 0.009439                1009.439041
# 3                 0.003701                1003.701321
# 4                 0.047650                1047.650341
# 5                 0.084745                1084.745405
# 6                 0.084628                1084.627848
# ...                    ...                        ...
# 1456              3.128501                4128.500862
# 1457              3.131917                4131.917348
# 1458              3.129932                4129.931653
# 1459              3.144212                4144.212259
# 1460              3.116859                4116.859017
#
#       pre_trade_notional_value  entry_fee  exit_fee  roundtrip_fees  \
# 2                  1000.000000   0.150000  0.151416        0.301416
# 3                  1009.439041   0.151416  0.150555        0.301971
# 4                  1003.701321   0.150555  0.157148        0.307703
# 5                  1047.650341   0.157148  0.162712        0.319859
# 6                  1084.745405   0.162712  0.162694        0.325406
# ...                        ...        ...       ...             ...
# 1456               4118.129196   0.617719  0.619275        1.236995
# 1457               4128.500862   0.619275  0.619788        1.239063
# 1458               4131.917348   0.619788  0.619490        1.239277
# 1459               4129.931653   0.619490  0.621632        1.241122
# 1460               4144.212259   0.621632  0.617529        1.239161
#
#       cum_roundtrip_fees   net_equity
# 2               0.301416  1009.137625
# 3               0.603387  1003.097934
# 4               0.911090  1046.739251
# 5               1.230949  1083.514456
# 6               1.556355  1083.071493
# ...                  ...          ...
# 1456         1142.772120  2985.728742
# 1457         1144.011183  2987.906165
# 1458         1145.250460  2984.681193
# 1459         1146.491582  2997.720677
# 1460         1147.730742  2969.128274
#
# [1459 rows x 25 columns]

# %%
df['net_equity'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Add transaction fees
# 2. Display equity curve factoring in fees
# 3. Add trade sizing starting with $12
